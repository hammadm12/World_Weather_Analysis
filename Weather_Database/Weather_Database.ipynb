# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\programdata\miniconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\programdata\miniconda3\lib\site-packages (from scipy) (1.21.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack zip file
coordinates = list(lat_lngs)

# %%
# Confirming last entry in random Latitudes and Longitudes set.
coordinates[1999]
# Out:
# (-13.359974018407556, 51.555863700035786)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0c6636dfffcafe142648a98a86712b0"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0c6636dfffcafe142648a98a86712b0

# %%
# Import the requests library.
import requests

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    print(city)
    
# Run an API request for each of the cities.
    try:
        print(city)
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        # print(city_lat)
        city_lng = city_weather["coord"]["lon"]
        # print(city_lng)
        city_max_temp = city_weather["main"]["temp_max"]
        # print(city_max_temp)
        city_humidity = city_weather["main"]["humidity"]
        # print(city_humidity)
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})
                          # "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# vaini
# vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77.16, 'feels_like': 78.01, 'temp_min': 77.16, 'temp_max': 77.16, 'pressure': 1017, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 150}, 'clouds': {'all': 20}, 'dt': 1632090958, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1632159108, 'sunset': 1632202582}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 2 of Set 1 | bayir
# bayir
# bayir
# {'coord': {'lon': 28.2167, 'lat': 37.2687}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.92, 'feels_like': 63.23, 'temp_min': 64.92, 'temp_max': 64.92, 'pressure': 1016, 'humidity': 45, 'sea_level': 1016, 'grnd_level': 968}, 'visibility': 10000, 'wind': {'speed': 1.48, 'deg': 114, 'gust': 1.99}, 'clouds': {'all': 3}, 'dt': 1632090958, 'sys': {'type': 1, 'id': 7016, 'country': 'TR', 'sunrise': 1632109996, 'sunset': 1632154079}, 'timezone': 10800, 'id': 304183, 'name': 'Bayir', 'cod': 200}
# Processing Record 3 of Set 1 | grand river south east
# grand river south east
# grand river south east
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 4 of Set 1 | jamestown
# jamestown
# jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 72.03, 'feels_like': 71.24, 'temp_min': 66.52, 'temp_max': 74.52, 'pressure': 1023, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 70}, 'clouds': {'all': 1}, 'dt': 1632090695, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1632049287, 'sunset': 1632093596}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 5 of Set 1 | mys shmidta
# mys shmidta
# mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 6 of Set 1 | acapulco
# acapulco
# acapulco
# {'coord': {'lon': -99.8901, 'lat': 16.8634}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 87.62, 'feels_like': 99.19, 'temp_min': 87.62, 'temp_max': 87.62, 'pressure': 1009, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 240}, 'clouds': {'all': 75}, 'dt': 1632090671, 'sys': {'type': 1, 'id': 7103, 'country': 'MX', 'sunrise': 1632054495, 'sunset': 1632098300}, 'timezone': -18000, 'id': 3533462, 'name': 'Acapulco de Juárez', 'cod': 200}
# Processing Record 7 of Set 1 | dunedin
# dunedin
# dunedin
# {'coord': {'lon': 170.5036, 'lat': -45.8742}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 55.8, 'feels_like': 54.03, 'temp_min': 55.8, 'temp_max': 55.8, 'pressure': 1004, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 14, 'deg': 5, 'gust': 21}, 'clouds': {'all': 52}, 'dt': 1632090958, 'sys': {'type': 2, 'id': 75281, 'country': 'NZ', 'sunrise': 1632076308, 'sunset': 1632119487}, 'timezone': 43200, 'id': 2191562, 'name': 'Dunedin', 'cod': 200}
# Processing Record 8 of Set 1 | kahului
# kahului
# kahului
# {'coord': {'lon': -156.47, 'lat': 20.8947}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 85.12, 'feels_like': 90.45, 'temp_min': 79.68, 'temp_max': 87.82, 'pressure': 1016, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 23.02, 'deg': 60, 'gust': 34.52}, 'clouds': {'all': 40}, 'dt': 1632090879, 'sys': {'type': 1, 'id': 7879, 'country': 'US', 'sunrise': 1632068046, 'sunset': 1632111900}, 'timezone': -36000, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# Processing Record 9 of Set 1 | airai
# airai
# airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 65.43, 'feels_like': 63.45, 'temp_min': 65.43, 'temp_max': 65.43, 'pressure': 1015, 'humidity': 38, 'sea_level': 1015, 'grnd_level': 860}, 'visibility': 10000, 'wind': {'speed': 4.56, 'deg': 117, 'gust': 10.2}, 'clouds': {'all': 32}, 'dt': 1632090958, 'sys': {'country': 'TL', 'sunrise': 1632086959, 'sunset': 1632130476}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 10 of Set 1 | avarua
# avarua
# avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.65, 'feels_like': 83.88, 'temp_min': 80.65, 'temp_max': 80.65, 'pressure': 1017, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1632090725, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1632069067, 'sunset': 1632112465}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Processing Record 11 of Set 1 | belushya guba
# belushya guba
# belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 12 of Set 1 | torbay
# torbay
# torbay
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}, {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 56.77, 'feels_like': 56.7, 'temp_min': 56.17, 'temp_max': 57.76, 'pressure': 1007, 'humidity': 97}, 'visibility': 604, 'wind': {'speed': 11.5, 'deg': 50, 'gust': 19.57}, 'rain': {'1h': 3.81}, 'clouds': {'all': 90}, 'dt': 1632090959, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1632042831, 'sunset': 1632087333}, 'timezone': -9000, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# Processing Record 13 of Set 1 | bluff
# bluff
# bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 54.81, 'feels_like': 53.22, 'temp_min': 54.81, 'temp_max': 54.81, 'pressure': 1004, 'humidity': 69, 'sea_level': 1004, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 16.89, 'deg': 345, 'gust': 24.36}, 'clouds': {'all': 82}, 'dt': 1632090945, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1632076832, 'sunset': 1632120004}, 'timezone': 43200, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 14 of Set 1 | rikitea
# rikitea
# rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.96, 'feels_like': 74.62, 'temp_min': 73.96, 'temp_max': 73.96, 'pressure': 1020, 'humidity': 76, 'sea_level': 1020, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 11.83, 'deg': 111, 'gust': 11.81}, 'clouds': {'all': 4}, 'dt': 1632090959, 'sys': {'country': 'PF', 'sunrise': 1632063126, 'sunset': 1632106502}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 15 of Set 1 | busselton
# busselton
# busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 43.05, 'feels_like': 37.06, 'temp_min': 43.05, 'temp_max': 44.1, 'pressure': 1035, 'humidity': 79, 'sea_level': 1035, 'grnd_level': 1035}, 'visibility': 10000, 'wind': {'speed': 10.94, 'deg': 102, 'gust': 25.79}, 'clouds': {'all': 0}, 'dt': 1632090949, 'sys': {'type': 2, 'id': 2020551, 'country': 'AU', 'sunrise': 1632089478, 'sunset': 1632132792}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 16 of Set 1 | new norfolk
# new norfolk
# new norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 43.79, 'feels_like': 43.79, 'temp_min': 40.91, 'temp_max': 48.92, 'pressure': 997, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 162, 'gust': 5.01}, 'clouds': {'all': 83}, 'dt': 1632090960, 'sys': {'type': 2, 'id': 2031307, 'country': 'AU', 'sunrise': 1632081912, 'sunset': 1632125133}, 'timezone': 36000, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# Processing Record 17 of Set 1 | katsuura
# katsuura
# katsuura
# {'coord': {'lon': 140.3, 'lat': 35.1333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.91, 'feels_like': 69.84, 'temp_min': 69.91, 'temp_max': 69.91, 'pressure': 1016, 'humidity': 69, 'sea_level': 1016, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 16.64, 'deg': 38, 'gust': 21.65}, 'clouds': {'all': 86}, 'dt': 1632090960, 'sys': {'type': 1, 'id': 8074, 'country': 'JP', 'sunrise': 1632083103, 'sunset': 1632127185}, 'timezone': 32400, 'id': 2112309, 'name': 'Katsuura', 'cod': 200}
# Processing Record 18 of Set 1 | haines junction
# haines junction
# haines junction
# {'coord': {'lon': -137.5108, 'lat': 60.7522}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.15, 'feels_like': 54.48, 'temp_min': 57.15, 'temp_max': 57.15, 'pressure': 1009, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 180}, 'clouds': {'all': 62}, 'dt': 1632090960, 'sys': {'type': 1, 'id': 287, 'country': 'CA', 'sunrise': 1632062877, 'sunset': 1632107971}, 'timezone': -25200, 'id': 5969025, 'name': 'Haines Junction', 'cod': 200}
# Processing Record 19 of Set 1 | saint-philippe
# saint-philippe
# saint-philippe
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 63.14, 'feels_like': 62.49, 'temp_min': 62.15, 'temp_max': 63.99, 'pressure': 1021, 'humidity': 71, 'sea_level': 1021, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 7.27, 'deg': 185, 'gust': 8.46}, 'clouds': {'all': 4}, 'dt': 1632090960, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1632103714, 'sunset': 1632147140}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# Processing Record 20 of Set 1 | hermanus
# hermanus
# hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 49.8, 'feels_like': 44.58, 'temp_min': 49.8, 'temp_max': 56.89, 'pressure': 1016, 'humidity': 77, 'sea_level': 1016, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 14.18, 'deg': 308, 'gust': 23.4}, 'clouds': {'all': 0}, 'dt': 1632090960, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1632112522, 'sunset': 1632155864}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 21 of Set 1 | hunsur
# hunsur
# hunsur
# {'coord': {'lon': 76.2878, 'lat': 12.3075}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68.63, 'feels_like': 69.57, 'temp_min': 68.63, 'temp_max': 68.63, 'pressure': 1011, 'humidity': 93, 'sea_level': 1011, 'grnd_level': 923}, 'visibility': 10000, 'wind': {'speed': 4.54, 'deg': 273, 'gust': 5.88}, 'clouds': {'all': 95}, 'dt': 1632090961, 'sys': {'country': 'IN', 'sunrise': 1632098642, 'sunset': 1632142365}, 'timezone': 19800, 'id': 1269873, 'name': 'Hunsūr', 'cod': 200}
# Processing Record 22 of Set 1 | boa vista
# boa vista
# boa vista
# {'coord': {'lon': -60.6733, 'lat': 2.8197}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.58, 'feels_like': 87.08, 'temp_min': 80.58, 'temp_max': 80.58, 'pressure': 1010, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 30}, 'clouds': {'all': 75}, 'dt': 1632090773, 'sys': {'type': 1, 'id': 8340, 'country': 'BR', 'sunrise': 1632045172, 'sunset': 1632088803}, 'timezone': -14400, 'id': 3664980, 'name': 'Boa Vista', 'cod': 200}
# Processing Record 23 of Set 1 | norman wells
# norman wells
# norman wells
# {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.84, 'feels_like': 49.64, 'temp_min': 51.84, 'temp_max': 51.84, 'pressure': 1005, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 280}, 'clouds': {'all': 75}, 'dt': 1632090961, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1632060123, 'sunset': 1632105601}, 'timezone': -21600, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# Processing Record 24 of Set 1 | thompson
# thompson
# thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.36, 'feels_like': 56.43, 'temp_min': 57.36, 'temp_max': 57.36, 'pressure': 994, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 280, 'gust': 24.16}, 'clouds': {'all': 75}, 'dt': 1632090961, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1632053497, 'sunset': 1632098322}, 'timezone': -18000, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# Processing Record 25 of Set 1 | mar del plata
# mar del plata
# mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.22, 'feels_like': 57.06, 'temp_min': 57.22, 'temp_max': 57.22, 'pressure': 1016, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 110}, 'clouds': {'all': 90}, 'dt': 1632090962, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1632044639, 'sunset': 1632087841}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 26 of Set 1 | labuan
# labuan
# labuan
# {'coord': {'lon': 115.2417, 'lat': 5.2767}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 77.36, 'feels_like': 78.93, 'temp_min': 77.16, 'temp_max': 77.36, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1632090962, 'sys': {'type': 1, 'id': 9372, 'country': 'MY', 'sunrise': 1632089331, 'sunset': 1632132982}, 'timezone': 28800, 'id': 1733782, 'name': 'Labuan', 'cod': 200}
# Processing Record 27 of Set 1 | souillac
# souillac
# souillac
# {'coord': {'lon': 57.5167, 'lat': -20.5167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 70.18, 'feels_like': 69.53, 'temp_min': 64.36, 'temp_max': 70.18, 'pressure': 1020, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1632090962, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1632103291, 'sunset': 1632146723}, 'timezone': 14400, 'id': 933995, 'name': 'Souillac', 'cod': 200}
# Processing Record 28 of Set 1 | flinders
# flinders
# flinders
# {'coord': {'lon': 150.8552, 'lat': -34.5833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 63.59, 'feels_like': 61.2, 'temp_min': 61.88, 'temp_max': 64.26, 'pressure': 1013, 'humidity': 33, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 326, 'gust': 23.29}, 'clouds': {'all': 0}, 'dt': 1632090962, 'sys': {'type': 2, 'id': 2010723, 'country': 'AU', 'sunrise': 1632080965, 'sunset': 1632124259}, 'timezone': 36000, 'id': 6255012, 'name': 'Flinders', 'cod': 200}
# Processing Record 29 of Set 1 | pisco
# pisco
# pisco
# {'coord': {'lon': -76.2167, 'lat': -13.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.65, 'feels_like': 62.24, 'temp_min': 62.02, 'temp_max': 62.65, 'pressure': 1013, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1632090963, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1632048989, 'sunset': 1632092445}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 30 of Set 1 | pokrovsk
# pokrovsk
# pokrovsk
# {'coord': {'lon': 37.1758, 'lat': 48.282}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 58.55, 'feels_like': 57.43, 'temp_min': 58.55, 'temp_max': 58.55, 'pressure': 1008, 'humidity': 71, 'sea_level': 1008, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 7.25, 'deg': 215, 'gust': 9.4}, 'clouds': {'all': 39}, 'dt': 1632090963, 'sys': {'country': 'UA', 'sunrise': 1632107704, 'sunset': 1632152072}, 'timezone': 10800, 'id': 704422, 'name': "Krasnoarmiys'k", 'cod': 200}
# Processing Record 31 of Set 1 | bur gabo
# bur gabo
# bur gabo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 32 of Set 1 | zeya
# zeya
# zeya
# {'coord': {'lon': 127.2667, 'lat': 53.75}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 43.5, 'feels_like': 43.5, 'temp_min': 43.5, 'temp_max': 43.5, 'pressure': 1014, 'humidity': 79, 'sea_level': 1014, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 1.28, 'deg': 152, 'gust': 1.36}, 'clouds': {'all': 43}, 'dt': 1632090963, 'sys': {'country': 'RU', 'sunrise': 1632085957, 'sunset': 1632130587}, 'timezone': 32400, 'id': 2012593, 'name': 'Zeya', 'cod': 200}
# Processing Record 33 of Set 1 | antalaha
# antalaha
# antalaha
# {'coord': {'lon': 50.2788, 'lat': -14.9003}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 69.91, 'feels_like': 70.59, 'temp_min': 69.91, 'temp_max': 69.91, 'pressure': 1017, 'humidity': 85, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 10.83, 'deg': 175, 'gust': 20.09}, 'rain': {'1h': 0.14}, 'clouds': {'all': 100}, 'dt': 1632090963, 'sys': {'country': 'MG', 'sunrise': 1632105006, 'sunset': 1632148482}, 'timezone': 10800, 'id': 1071296, 'name': 'Antalaha', 'cod': 200}
# Processing Record 34 of Set 1 | sentyabrskiy
# sentyabrskiy
# sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 35 of Set 1 | portland
# portland
# portland
# {'coord': {'lon': -122.6762, 'lat': 45.5234}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 63.9, 'feels_like': 63.64, 'temp_min': 58.62, 'temp_max': 69.13, 'pressure': 1020, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 223, 'gust': 11.99}, 'clouds': {'all': 75}, 'dt': 1632090665, 'sys': {'type': 2, 'id': 2008548, 'country': 'US', 'sunrise': 1632059669, 'sunset': 1632104060}, 'timezone': -25200, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# Processing Record 36 of Set 1 | okato
# okato
# okato
# {'coord': {'lon': 173.8833, 'lat': -39.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.69, 'feels_like': 52.29, 'temp_min': 53.69, 'temp_max': 56.43, 'pressure': 1016, 'humidity': 75, 'sea_level': 1016, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 266, 'gust': 18.52}, 'clouds': {'all': 82}, 'dt': 1632090964, 'sys': {'type': 2, 'id': 2020402, 'country': 'NZ', 'sunrise': 1632075465, 'sunset': 1632118708}, 'timezone': 43200, 'id': 2185763, 'name': 'Okato', 'cod': 200}
# Processing Record 37 of Set 1 | codrington
# codrington
# codrington
# {'coord': {'lon': 141.9667, 'lat': -38.2667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 48.69, 'feels_like': 41.61, 'temp_min': 48.69, 'temp_max': 48.69, 'pressure': 1013, 'humidity': 78, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 21.45, 'deg': 259, 'gust': 31.52}, 'rain': {'1h': 0.13}, 'clouds': {'all': 53}, 'dt': 1632090964, 'sys': {'country': 'AU', 'sunrise': 1632083112, 'sunset': 1632126377}, 'timezone': 36000, 'id': 2171099, 'name': 'Codrington', 'cod': 200}
# Processing Record 38 of Set 1 | vagur
# vagur
# vagur
# {'coord': {'lon': -6.8119, 'lat': 61.4732}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 52.05, 'feels_like': 51.13, 'temp_min': 52.05, 'temp_max': 52.05, 'pressure': 1013, 'humidity': 89, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 13.47, 'deg': 200, 'gust': 18.59}, 'clouds': {'all': 9}, 'dt': 1632090964, 'sys': {'country': 'FO', 'sunrise': 1632031429, 'sunset': 1632076700}, 'timezone': 3600, 'id': 2610806, 'name': 'Vágur', 'cod': 200}
# Processing Record 39 of Set 1 | kapaa
# kapaa
# kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 79.05, 'feels_like': 79.05, 'temp_min': 77.32, 'temp_max': 81.48, 'pressure': 1018, 'humidity': 76}, 'visibility': 4828, 'wind': {'speed': 4, 'deg': 343, 'gust': 10}, 'rain': {'1h': 0.77}, 'clouds': {'all': 75}, 'dt': 1632090964, 'sys': {'type': 2, 'id': 2001562, 'country': 'US', 'sunrise': 1632068722, 'sunset': 1632112592}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 40 of Set 1 | port alfred
# port alfred
# port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 60.48, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1014, 'humidity': 83, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 10.67, 'deg': 258, 'gust': 13.69}, 'clouds': {'all': 71}, 'dt': 1632090965, 'sys': {'country': 'ZA', 'sunrise': 1632110683, 'sunset': 1632154028}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 41 of Set 1 | teahupoo
# teahupoo
# teahupoo
# {'coord': {'lon': -149.2667, 'lat': -17.8333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.96, 'feels_like': 77.79, 'temp_min': 76.96, 'temp_max': 76.96, 'pressure': 1016, 'humidity': 73, 'sea_level': 1016, 'grnd_level': 963}, 'visibility': 10000, 'wind': {'speed': 18.05, 'deg': 89, 'gust': 18.34}, 'clouds': {'all': 65}, 'dt': 1632090965, 'sys': {'type': 1, 'id': 7318, 'country': 'PF', 'sunrise': 1632066531, 'sunset': 1632109958}, 'timezone': -36000, 'id': 4033543, 'name': 'Teahupoo', 'cod': 200}
# Processing Record 42 of Set 1 | alofi
# alofi
# alofi
# {'coord': {'lon': -169.9187, 'lat': -19.0595}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.29, 'feels_like': 74.46, 'temp_min': 73.29, 'temp_max': 73.29, 'pressure': 1015, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 160}, 'clouds': {'all': 0}, 'dt': 1632090965, 'sys': {'type': 1, 'id': 7306, 'country': 'NU', 'sunrise': 1632071490, 'sunset': 1632114909}, 'timezone': -39600, 'id': 4036284, 'name': 'Alofi', 'cod': 200}
# Processing Record 43 of Set 1 | victoria
# victoria
# victoria
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.18, 'feels_like': 96.78, 'temp_min': 82.36, 'temp_max': 85.32, 'pressure': 1010, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 5.55, 'deg': 78, 'gust': 6.29}, 'clouds': {'all': 18}, 'dt': 1632090965, 'sys': {'type': 2, 'id': 2035800, 'country': 'HK', 'sunrise': 1632089489, 'sunset': 1632133344}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# Processing Record 44 of Set 1 | albany
# albany
# albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.38, 'feels_like': 61.9, 'temp_min': 59.63, 'temp_max': 69.39, 'pressure': 1019, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 2.21, 'deg': 19, 'gust': 2.55}, 'clouds': {'all': 5}, 'dt': 1632090965, 'sys': {'type': 2, 'id': 19530, 'country': 'US', 'sunrise': 1632048014, 'sunset': 1632092341}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 45 of Set 1 | cape town
# cape town
# cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 54.88, 'temp_min': 54.88, 'temp_max': 57.11, 'pressure': 1018, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 203, 'gust': 3}, 'clouds': {'all': 75}, 'dt': 1632090770, 'sys': {'type': 2, 'id': 2033665, 'country': 'ZA', 'sunrise': 1632112714, 'sunset': 1632156060}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 46 of Set 1 | bonavista
# bonavista
# bonavista
# {'coord': {'lon': -53.1147, 'lat': 48.6499}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 53.22, 'temp_min': 53.6, 'temp_max': 57.11, 'pressure': 1012, 'humidity': 97, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 8529, 'wind': {'speed': 18.92, 'deg': 21, 'gust': 28.05}, 'rain': {'1h': 0.93}, 'clouds': {'all': 100}, 'dt': 1632090699, 'sys': {'type': 1, 'id': 719, 'country': 'CA', 'sunrise': 1632042905, 'sunset': 1632087444}, 'timezone': -9000, 'id': 5905393, 'name': 'Bonavista', 'cod': 200}
# Processing Record 47 of Set 1 | yellowknife
# yellowknife
# yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 50.52, 'feels_like': 48.18, 'temp_min': 50.52, 'temp_max': 50.52, 'pressure': 1004, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1632090966, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1632057246, 'sunset': 1632102489}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 48 of Set 1 | byron bay
# byron bay
# byron bay
# {'coord': {'lon': 153.6167, 'lat': -28.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 65.43, 'feels_like': 64.58, 'temp_min': 62.56, 'temp_max': 74.05, 'pressure': 1020, 'humidity': 62, 'sea_level': 1020, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 11.63, 'deg': 342, 'gust': 15.48}, 'clouds': {'all': 3}, 'dt': 1632090966, 'sys': {'type': 1, 'id': 9496, 'country': 'AU', 'sunrise': 1632080277, 'sunset': 1632123621}, 'timezone': 36000, 'id': 2172880, 'name': 'Byron Bay', 'cod': 200}
# Processing Record 49 of Set 1 | kodiak
# kodiak
# kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 51.31, 'feels_like': 49.71, 'temp_min': 51.31, 'temp_max': 51.31, 'pressure': 1002, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 100}, 'clouds': {'all': 20}, 'dt': 1632090966, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1632066551, 'sunset': 1632111445}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 50 of Set 1 | la ronge
# la ronge
# la ronge
# {'coord': {'lon': -105.2842, 'lat': 55.1001}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.45, 'feels_like': 54.97, 'temp_min': 57.45, 'temp_max': 59.22, 'pressure': 1001, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 300, 'gust': 23.02}, 'clouds': {'all': 75}, 'dt': 1632090966, 'sys': {'type': 1, 'id': 696, 'country': 'CA', 'sunrise': 1632055299, 'sunset': 1632100085}, 'timezone': -21600, 'id': 6050066, 'name': 'La Ronge', 'cod': 200}
# Processing Record 1 of Set 2 | dafeng
# dafeng
# dafeng
# {'coord': {'lon': 108.5881, 'lat': 23.4517}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.32, 'feels_like': 78.98, 'temp_min': 77.32, 'temp_max': 77.32, 'pressure': 1012, 'humidity': 90, 'sea_level': 1012, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 348, 'gust': 1.52}, 'clouds': {'all': 99}, 'dt': 1632090967, 'sys': {'country': 'CN', 'sunrise': 1632090818, 'sunset': 1632134689}, 'timezone': 28800, 'id': 1814435, 'name': 'Dafeng', 'cod': 200}
# Processing Record 2 of Set 2 | kaitangata
# kaitangata
# kaitangata
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.24, 'feels_like': 51.17, 'temp_min': 53.24, 'temp_max': 53.24, 'pressure': 1005, 'humidity': 62, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 352, 'gust': 10.67}, 'clouds': {'all': 55}, 'dt': 1632090967, 'sys': {'country': 'NZ', 'sunrise': 1632076468, 'sunset': 1632119642}, 'timezone': 43200, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 3 of Set 2 | glendive
# glendive
# glendive
# {'coord': {'lon': -104.7125, 'lat': 47.1053}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 54.05, 'feels_like': 52.83, 'temp_min': 45.66, 'temp_max': 68.63, 'pressure': 999, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 292, 'gust': 15.01}, 'clouds': {'all': 99}, 'dt': 1632090967, 'sys': {'type': 2, 'id': 2020770, 'country': 'US', 'sunrise': 1632055328, 'sunset': 1632099781}, 'timezone': -21600, 'id': 5654391, 'name': 'Glendive', 'cod': 200}
# Processing Record 4 of Set 2 | kargasok
# kargasok
# kargasok
# {'coord': {'lon': 80.8572, 'lat': 59.0556}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 36.07, 'feels_like': 30.02, 'temp_min': 36.07, 'temp_max': 36.07, 'pressure': 1001, 'humidity': 97, 'sea_level': 1001, 'grnd_level': 994}, 'visibility': 4247, 'wind': {'speed': 7.61, 'deg': 231, 'gust': 13}, 'clouds': {'all': 100}, 'dt': 1632090727, 'sys': {'country': 'RU', 'sunrise': 1632096977, 'sunset': 1632141837}, 'timezone': 25200, 'id': 1504382, 'name': 'Kargasok', 'cod': 200}
# Processing Record 5 of Set 2 | ilinsko-podomskoye
# ilinsko-podomskoye
# ilinsko-podomskoye
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 6 of Set 2 | mataura
# mataura
# mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 54.48, 'feels_like': 52.27, 'temp_min': 54.48, 'temp_max': 54.48, 'pressure': 1005, 'humidity': 56, 'sea_level': 1005, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 6.11, 'deg': 342, 'gust': 20.92}, 'clouds': {'all': 64}, 'dt': 1632090967, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1632076703, 'sunset': 1632119879}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 7 of Set 2 | punta arenas
# punta arenas
# punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 42.91, 'feels_like': 34.95, 'temp_min': 42.91, 'temp_max': 42.91, 'pressure': 1010, 'humidity': 87}, 'visibility': 8000, 'wind': {'speed': 17.27, 'deg': 260}, 'clouds': {'all': 90}, 'dt': 1632090929, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1632047939, 'sunset': 1632090952}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 8 of Set 2 | alegrete
# alegrete
# alegrete
# {'coord': {'lon': -55.7919, 'lat': -29.7831}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 70.97, 'feels_like': 72.09, 'temp_min': 70.97, 'temp_max': 70.97, 'pressure': 1008, 'humidity': 92, 'sea_level': 1008, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 15.3, 'deg': 109, 'gust': 27.81}, 'clouds': {'all': 90}, 'dt': 1632090968, 'sys': {'country': 'BR', 'sunrise': 1632044172, 'sunset': 1632087461}, 'timezone': -10800, 'id': 3472638, 'name': 'Alegrete', 'cod': 200}
# Processing Record 9 of Set 2 | annau
# annau
# annau
# {'coord': {'lon': 58.516, 'lat': 37.8876}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.3, 'feels_like': 67.15, 'temp_min': 69.3, 'temp_max': 69.3, 'pressure': 1014, 'humidity': 26}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 110}, 'clouds': {'all': 0}, 'dt': 1632090968, 'sys': {'type': 1, 'id': 8992, 'country': 'TM', 'sunrise': 1632102713, 'sunset': 1632146822}, 'timezone': 18000, 'id': 162199, 'name': 'Annau', 'cod': 200}
# Processing Record 10 of Set 2 | bredasdorp
# bredasdorp
# bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 52.92, 'feels_like': 51.76, 'temp_min': 49.28, 'temp_max': 52.92, 'pressure': 1016, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1632090954, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1632112329, 'sunset': 1632155670}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 11 of Set 2 | ribeira grande
# ribeira grande
# ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.93, 'feels_like': 69.82, 'temp_min': 69.93, 'temp_max': 69.93, 'pressure': 1030, 'humidity': 68, 'sea_level': 1030, 'grnd_level': 1030}, 'visibility': 10000, 'wind': {'speed': 10.47, 'deg': 100, 'gust': 11.27}, 'clouds': {'all': 36}, 'dt': 1632090968, 'sys': {'country': 'PT', 'sunrise': 1632037199, 'sunset': 1632081433}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 12 of Set 2 | bengkulu
# bengkulu
# bengkulu
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 73.33, 'feels_like': 74.59, 'temp_min': 73.33, 'temp_max': 73.33, 'pressure': 1012, 'humidity': 90, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.75, 'deg': 64, 'gust': 2.89}, 'rain': {'1h': 1.86}, 'clouds': {'all': 82}, 'dt': 1632090952, 'sys': {'country': 'ID', 'sunrise': 1632092489, 'sunset': 1632136052}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# Processing Record 13 of Set 2 | atuona
# atuona
# atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.31, 'feels_like': 79.47, 'temp_min': 78.31, 'temp_max': 78.31, 'pressure': 1013, 'humidity': 77, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 21.56, 'deg': 96, 'gust': 22.5}, 'clouds': {'all': 33}, 'dt': 1632090942, 'sys': {'country': 'PF', 'sunrise': 1632064039, 'sunset': 1632107540}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 14 of Set 2 | kilrush
# kilrush
# kilrush
# {'coord': {'lon': -9.4833, 'lat': 52.6397}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.15, 'feels_like': 54.73, 'temp_min': 55.15, 'temp_max': 55.89, 'pressure': 1021, 'humidity': 93, 'sea_level': 1021, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 7.27, 'deg': 244, 'gust': 12.59}, 'clouds': {'all': 73}, 'dt': 1632090968, 'sys': {'type': 1, 'id': 1569, 'country': 'IE', 'sunrise': 1632032338, 'sunset': 1632077073}, 'timezone': 3600, 'id': 2963218, 'name': 'Kilrush', 'cod': 200}
# Processing Record 15 of Set 2 | duverge
# duverge
# duverge
# {'coord': {'lon': -71.5247, 'lat': 18.3784}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 86.05, 'feels_like': 96.1, 'temp_min': 86.05, 'temp_max': 86.05, 'pressure': 1013, 'humidity': 72, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.98, 'deg': 87, 'gust': 5.75}, 'clouds': {'all': 39}, 'dt': 1632090969, 'sys': {'type': 1, 'id': 7048, 'country': 'DO', 'sunrise': 1632047675, 'sunset': 1632091507}, 'timezone': -14400, 'id': 3508694, 'name': 'Duvergé', 'cod': 200}
# Processing Record 16 of Set 2 | bogorodskoye
# bogorodskoye
# bogorodskoye
# {'coord': {'lon': 37.8833, 'lat': 56.55}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 41.83, 'feels_like': 33.82, 'temp_min': 41.83, 'temp_max': 41.83, 'pressure': 1021, 'humidity': 62, 'sea_level': 1021, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 16.26, 'deg': 82, 'gust': 32.53}, 'rain': {'1h': 1.42}, 'clouds': {'all': 100}, 'dt': 1632090969, 'sys': {'country': 'RU', 'sunrise': 1632107372, 'sunset': 1632152064}, 'timezone': 10800, 'id': 575521, 'name': 'Bogorodskoye', 'cod': 200}
# Processing Record 17 of Set 2 | hilo
# hilo
# hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 75.92, 'feels_like': 77.16, 'temp_min': 74.93, 'temp_max': 81.25, 'pressure': 1018, 'humidity': 84}, 'visibility': 8047, 'wind': {'speed': 0, 'deg': 0}, 'rain': {'1h': 0.51}, 'clouds': {'all': 90}, 'dt': 1632090969, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1632067724, 'sunset': 1632111560}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 18 of Set 2 | guaraciaba do norte
# guaraciaba do norte
# guaraciaba do norte
# {'coord': {'lon': -40.7475, 'lat': -4.1669}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.51, 'feels_like': 75.88, 'temp_min': 76.51, 'temp_max': 76.51, 'pressure': 1011, 'humidity': 43, 'sea_level': 1011, 'grnd_level': 914}, 'visibility': 10000, 'wind': {'speed': 7.43, 'deg': 34, 'gust': 17.49}, 'clouds': {'all': 89}, 'dt': 1632090941, 'sys': {'country': 'BR', 'sunrise': 1632040431, 'sunset': 1632083983}, 'timezone': -10800, 'id': 3398569, 'name': 'Guaraciaba do Norte', 'cod': 200}
# Processing Record 19 of Set 2 | provideniya
# provideniya
# provideniya
# {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 33.91, 'feels_like': 24.6, 'temp_min': 33.91, 'temp_max': 33.91, 'pressure': 1014, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 13.42, 'deg': 10}, 'clouds': {'all': 20}, 'dt': 1632090969, 'sys': {'type': 1, 'id': 8875, 'country': 'RU', 'sunrise': 1632157912, 'sunset': 1632202866}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# Processing Record 20 of Set 2 | puerto ayora
# puerto ayora
# puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 70.56, 'feels_like': 71.46, 'temp_min': 70.56, 'temp_max': 76.96, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 162, 'gust': 11.99}, 'clouds': {'all': 75}, 'dt': 1632090970, 'sys': {'type': 2, 'id': 2005652, 'country': 'EC', 'sunrise': 1632052313, 'sunset': 1632095904}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 21 of Set 2 | barrow
# barrow
# barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 30.22, 'feels_like': 18.14, 'temp_min': 30.22, 'temp_max': 30.22, 'pressure': 994, 'humidity': 86}, 'visibility': 3219, 'wind': {'speed': 18.41, 'deg': 210}, 'snow': {'1h': 0.13}, 'clouds': {'all': 90}, 'dt': 1632090881, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1632066950, 'sunset': 1632113149}, 'timezone': -28800, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 22 of Set 2 | butaritari
# butaritari
# butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.05, 'feels_like': 88.21, 'temp_min': 83.05, 'temp_max': 83.05, 'pressure': 1010, 'humidity': 69, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 14.65, 'deg': 112, 'gust': 16.06}, 'clouds': {'all': 65}, 'dt': 1632090970, 'sys': {'country': 'KI', 'sunrise': 1632075534, 'sunset': 1632119164}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 23 of Set 2 | sun prairie
# sun prairie
# sun prairie
# {'coord': {'lon': -89.2137, 'lat': 43.1836}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 86.18, 'feels_like': 87.58, 'temp_min': 81.88, 'temp_max': 90.68, 'pressure': 1013, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 178, 'gust': 3}, 'clouds': {'all': 20}, 'dt': 1632090814, 'sys': {'type': 2, 'id': 2012040, 'country': 'US', 'sunrise': 1632051667, 'sunset': 1632096004}, 'timezone': -18000, 'id': 5275020, 'name': 'Sun Prairie', 'cod': 200}
# Processing Record 24 of Set 2 | taolanaro
# taolanaro
# taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 25 of Set 2 | leningradskiy
# leningradskiy
# leningradskiy
# {'coord': {'lon': 178.4167, 'lat': 69.3833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 28.65, 'feels_like': 16.05, 'temp_min': 28.65, 'temp_max': 28.65, 'pressure': 1015, 'humidity': 83, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 21.18, 'deg': 288, 'gust': 29.46}, 'clouds': {'all': 93}, 'dt': 1632090970, 'sys': {'country': 'RU', 'sunrise': 1632073059, 'sunset': 1632118938}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# Processing Record 26 of Set 2 | ahipara
# ahipara
# ahipara
# {'coord': {'lon': 173.1667, 'lat': -35.1667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 60.46, 'feels_like': 59.25, 'temp_min': 60.46, 'temp_max': 60.46, 'pressure': 1019, 'humidity': 65, 'sea_level': 1019, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 6.96, 'deg': 237, 'gust': 10.94}, 'clouds': {'all': 16}, 'dt': 1632090970, 'sys': {'country': 'NZ', 'sunrise': 1632075618, 'sunset': 1632118899}, 'timezone': 43200, 'id': 2194098, 'name': 'Ahipara', 'cod': 200}
# Processing Record 27 of Set 2 | palabuhanratu
# palabuhanratu
# palabuhanratu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 28 of Set 2 | otradnoye
# otradnoye
# otradnoye
# {'coord': {'lon': 30.8181, 'lat': 59.7775}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 41.05, 'feels_like': 35.35, 'temp_min': 40.17, 'temp_max': 41.05, 'pressure': 1027, 'humidity': 77, 'sea_level': 1027, 'grnd_level': 1025}, 'visibility': 10000, 'wind': {'speed': 9.08, 'deg': 64, 'gust': 25.99}, 'clouds': {'all': 100}, 'dt': 1632090971, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1632108984, 'sunset': 1632153842}, 'timezone': 10800, 'id': 513898, 'name': 'Otradnoye', 'cod': 200}
# Processing Record 29 of Set 2 | xingcheng
# xingcheng
# xingcheng
# {'coord': {'lon': 120.7167, 'lat': 40.6167}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 64.06, 'feels_like': 64.67, 'temp_min': 64.06, 'temp_max': 64.06, 'pressure': 1009, 'humidity': 96, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 2770, 'wind': {'speed': 22.64, 'deg': 61, 'gust': 31.54}, 'rain': {'1h': 2.49}, 'clouds': {'all': 100}, 'dt': 1632090971, 'sys': {'country': 'CN', 'sunrise': 1632087744, 'sunset': 1632131942}, 'timezone': 28800, 'id': 2033766, 'name': 'Xingcheng', 'cod': 200}
# Processing Record 30 of Set 2 | castro
# castro
# castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.31, 'feels_like': 64.9, 'temp_min': 64.31, 'temp_max': 64.31, 'pressure': 1016, 'humidity': 95, 'sea_level': 1016, 'grnd_level': 905}, 'visibility': 10000, 'wind': {'speed': 4.27, 'deg': 43, 'gust': 7.9}, 'clouds': {'all': 51}, 'dt': 1632090971, 'sys': {'country': 'BR', 'sunrise': 1632042760, 'sunset': 1632086099}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 31 of Set 2 | saskylakh
# saskylakh
# saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 28.35, 'feels_like': 22.84, 'temp_min': 28.35, 'temp_max': 28.35, 'pressure': 1016, 'humidity': 93, 'sea_level': 1016, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 4.94, 'deg': 100, 'gust': 12.33}, 'clouds': {'all': 100}, 'dt': 1632090971, 'sys': {'country': 'RU', 'sunrise': 1632088352, 'sunset': 1632134517}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 32 of Set 2 | san andres
# san andres
# san andres
# {'coord': {'lon': -81.7006, 'lat': 12.5847}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86.02, 'feels_like': 96.93, 'temp_min': 86.02, 'temp_max': 86.02, 'pressure': 1009, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 70}, 'clouds': {'all': 75}, 'dt': 1632090972, 'sys': {'type': 1, 'id': 8623, 'country': 'CO', 'sunrise': 1632050158, 'sunset': 1632093908}, 'timezone': -18000, 'id': 3670218, 'name': 'San Andrés', 'cod': 200}
# Processing Record 33 of Set 2 | luderitz
# luderitz
# luderitz
# {'coord': {'lon': 15.1594, 'lat': -26.6481}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 54.1, 'feels_like': 53.26, 'temp_min': 54.1, 'temp_max': 54.1, 'pressure': 1020, 'humidity': 86, 'sea_level': 1020, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 9.82, 'deg': 164, 'gust': 13.67}, 'clouds': {'all': 0}, 'dt': 1632090972, 'sys': {'country': 'NA', 'sunrise': 1632113472, 'sunset': 1632156869}, 'timezone': 7200, 'id': 3355672, 'name': 'Lüderitz', 'cod': 200}
# Processing Record 34 of Set 2 | tuggurt
# tuggurt
# tuggurt
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 35 of Set 2 | tateyama
# tateyama
# tateyama
# ...
# Processing Record 33 of Set 15 | ballina
# ballina
# ballina
# {'coord': {'lon': 153.5667, 'lat': -28.8667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 65.66, 'feels_like': 65.79, 'temp_min': 62.64, 'temp_max': 66.16, 'pressure': 1019, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 30}, 'clouds': {'all': 40}, 'dt': 1632091097, 'sys': {'type': 1, 'id': 9496, 'country': 'AU', 'sunrise': 1632080290, 'sunset': 1632123632}, 'timezone': 36000, 'id': 2177069, 'name': 'Ballina', 'cod': 200}
# Processing Record 34 of Set 15 | santa cruz
# santa cruz
# santa cruz
# {'coord': {'lon': -63.1667, 'lat': -17.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 87.85, 'feels_like': 91.17, 'temp_min': 87.85, 'temp_max': 89.06, 'pressure': 1006, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 310, 'gust': 26.46}, 'clouds': {'all': 31}, 'dt': 1632090955, 'sys': {'type': 1, 'id': 8616, 'country': 'BO', 'sunrise': 1632045880, 'sunset': 1632089292}, 'timezone': -14400, 'id': 3904906, 'name': 'Santa Cruz de la Sierra', 'cod': 200}
# Processing Record 35 of Set 15 | pacific grove
# pacific grove
# pacific grove
# {'coord': {'lon': -121.9166, 'lat': 36.6177}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.73, 'feels_like': 69.87, 'temp_min': 64.09, 'temp_max': 82.58, 'pressure': 1017, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 316, 'gust': 15.99}, 'clouds': {'all': 1}, 'dt': 1632091097, 'sys': {'type': 2, 'id': 2009350, 'country': 'US', 'sunrise': 1632059607, 'sunset': 1632103758}, 'timezone': -25200, 'id': 5380437, 'name': 'Pacific Grove', 'cod': 200}
# Processing Record 36 of Set 15 | severomorsk
# severomorsk
# severomorsk
# {'coord': {'lon': 33.4162, 'lat': 69.0689}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 27, 'feels_like': 18.27, 'temp_min': 27, 'temp_max': 27, 'pressure': 1035, 'humidity': 78, 'sea_level': 1035, 'grnd_level': 1029}, 'visibility': 10000, 'wind': {'speed': 8.75, 'deg': 202, 'gust': 10.96}, 'clouds': {'all': 17}, 'dt': 1632091097, 'sys': {'type': 1, 'id': 8927, 'country': 'RU', 'sunrise': 1632107970, 'sunset': 1632153610}, 'timezone': 10800, 'id': 496278, 'name': 'Severomorsk', 'cod': 200}
# Processing Record 37 of Set 15 | bemidji
# bemidji
# bemidji
# {'coord': {'lon': -94.8803, 'lat': 47.4736}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.35, 'feels_like': 81.88, 'temp_min': 73.08, 'temp_max': 82.69, 'pressure': 1004, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 190, 'gust': 17.27}, 'clouds': {'all': 1}, 'dt': 1632091008, 'sys': {'type': 1, 'id': 3448, 'country': 'US', 'sunrise': 1632052959, 'sunset': 1632097431}, 'timezone': -18000, 'id': 5017822, 'name': 'Bemidji', 'cod': 200}
# Processing Record 38 of Set 15 | nome
# nome
# nome
# {'coord': {'lon': -165.4064, 'lat': 64.5011}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 39.27, 'feels_like': 33.67, 'temp_min': 39.11, 'temp_max': 40.15, 'pressure': 1007, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 340}, 'clouds': {'all': 40}, 'dt': 1632091097, 'sys': {'type': 1, 'id': 7770, 'country': 'US', 'sunrise': 1632069436, 'sunset': 1632114798}, 'timezone': -28800, 'id': 5870133, 'name': 'Nome', 'cod': 200}
# Processing Record 39 of Set 15 | darnah
# darnah
# darnah
# {'coord': {'lon': 22.6367, 'lat': 32.767}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.89, 'feels_like': 78.89, 'temp_min': 78.89, 'temp_max': 78.89, 'pressure': 1017, 'humidity': 55, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 4.25, 'deg': 299, 'gust': 4.47}, 'clouds': {'all': 0}, 'dt': 1632091098, 'sys': {'country': 'LY', 'sunrise': 1632111378, 'sunset': 1632155374}, 'timezone': 7200, 'id': 87205, 'name': 'Darnah', 'cod': 200}
# Processing Record 40 of Set 15 | avera
# avera
# avera
# {'coord': {'lon': -82.5271, 'lat': 33.194}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.24, 'feels_like': 82.96, 'temp_min': 76.51, 'temp_max': 84.07, 'pressure': 1016, 'humidity': 67, 'sea_level': 1016, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 7.45, 'deg': 97, 'gust': 15.9}, 'clouds': {'all': 100}, 'dt': 1632091098, 'sys': {'type': 1, 'id': 2827, 'country': 'US', 'sunrise': 1632050186, 'sunset': 1632094276}, 'timezone': -14400, 'id': 4231997, 'name': 'Avera', 'cod': 200}
# Processing Record 41 of Set 15 | ulaangom
# ulaangom
# ulaangom
# {'coord': {'lon': 92.0667, 'lat': 49.9811}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 51.73, 'feels_like': 47.91, 'temp_min': 51.73, 'temp_max': 51.73, 'pressure': 1001, 'humidity': 28, 'sea_level': 1001, 'grnd_level': 896}, 'visibility': 10000, 'wind': {'speed': 3.06, 'deg': 259, 'gust': 3.62}, 'clouds': {'all': 2}, 'dt': 1632091098, 'sys': {'country': 'MN', 'sunrise': 1632094488, 'sunset': 1632138946}, 'timezone': 25200, 'id': 1515029, 'name': 'Ulaangom', 'cod': 200}
# Processing Record 42 of Set 15 | athmallik
# athmallik
# athmallik
# {'coord': {'lon': 84.5348, 'lat': 20.7219}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.44, 'feels_like': 78.21, 'temp_min': 76.44, 'temp_max': 76.44, 'pressure': 1007, 'humidity': 94, 'sea_level': 1007, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 2.28, 'deg': 286, 'gust': 2.39}, 'clouds': {'all': 100}, 'dt': 1632091098, 'sys': {'country': 'IN', 'sunrise': 1632096611, 'sunset': 1632140438}, 'timezone': 19800, 'id': 1268610, 'name': 'Athmallik', 'cod': 200}
# Processing Record 43 of Set 15 | khuzhir
# khuzhir
# khuzhir
# {'coord': {'lon': 107.3397, 'lat': 53.1939}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 52.3, 'feels_like': 50.81, 'temp_min': 52.3, 'temp_max': 52.3, 'pressure': 1009, 'humidity': 76, 'sea_level': 1009, 'grnd_level': 954}, 'visibility': 10000, 'wind': {'speed': 7.25, 'deg': 43, 'gust': 9.1}, 'clouds': {'all': 3}, 'dt': 1632091099, 'sys': {'country': 'RU', 'sunrise': 1632090757, 'sunset': 1632135349}, 'timezone': 28800, 'id': 2022143, 'name': 'Khuzhir', 'cod': 200}
# Processing Record 44 of Set 15 | acajutla
# acajutla
# acajutla
# {'coord': {'lon': -89.8275, 'lat': 13.5928}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 97.14, 'feels_like': 109.74, 'temp_min': 97.14, 'temp_max': 97.14, 'pressure': 1010, 'humidity': 78, 'sea_level': 1010, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 268, 'gust': 6.49}, 'clouds': {'all': 98}, 'dt': 1632091099, 'sys': {'type': 1, 'id': 7209, 'country': 'SV', 'sunrise': 1632052102, 'sunset': 1632095864}, 'timezone': -21600, 'id': 3587498, 'name': 'Acajutla', 'cod': 200}
# Processing Record 45 of Set 15 | pundaguitan
# pundaguitan
# pundaguitan
# {'coord': {'lon': 126.1689, 'lat': 6.3711}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.38, 'feels_like': 84.6, 'temp_min': 80.38, 'temp_max': 80.38, 'pressure': 1011, 'humidity': 77, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 6804, 'wind': {'speed': 4.14, 'deg': 297, 'gust': 7.2}, 'clouds': {'all': 95}, 'dt': 1632091099, 'sys': {'country': 'PH', 'sunrise': 1632086704, 'sunset': 1632130366}, 'timezone': 28800, 'id': 1698289, 'name': 'Pundaguitan', 'cod': 200}
# Processing Record 46 of Set 15 | timizart
# timizart
# timizart
# {'coord': {'lon': 4.2667, 'lat': 36.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.08, 'feels_like': 69.58, 'temp_min': 69.08, 'temp_max': 69.08, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 981}, 'visibility': 10000, 'wind': {'speed': 5.48, 'deg': 95, 'gust': 5.79}, 'clouds': {'all': 0}, 'dt': 1632091099, 'sys': {'country': 'DZ', 'sunrise': 1632029304, 'sunset': 1632073508}, 'timezone': 3600, 'id': 2476396, 'name': 'Timizart', 'cod': 200}
# Processing Record 47 of Set 15 | launceston
# launceston
# launceston
# {'coord': {'lon': 147.1667, 'lat': -41.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 48.24, 'feels_like': 46.15, 'temp_min': 44.47, 'temp_max': 49.8, 'pressure': 1001, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 324, 'gust': 14}, 'clouds': {'all': 90}, 'dt': 1632091099, 'sys': {'type': 2, 'id': 2031746, 'country': 'AU', 'sunrise': 1632081880, 'sunset': 1632125114}, 'timezone': 36000, 'id': 2160517, 'name': 'Launceston', 'cod': 200}
# Processing Record 48 of Set 15 | sabang
# sabang
# sabang
# {'coord': {'lon': 95.3214, 'lat': 5.8933}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 78.01, 'feels_like': 79.45, 'temp_min': 78.01, 'temp_max': 78.01, 'pressure': 1011, 'humidity': 84, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 26.75, 'deg': 212, 'gust': 28.63}, 'rain': {'1h': 0.95}, 'clouds': {'all': 100}, 'dt': 1632091100, 'sys': {'country': 'ID', 'sunrise': 1632094108, 'sunset': 1632137765}, 'timezone': 25200, 'id': 1214026, 'name': 'Sabang', 'cod': 200}
# Processing Record 49 of Set 15 | falun
# falun
# falun
# {'coord': {'lon': 15.626, 'lat': 60.6036}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 43.21, 'feels_like': 43.21, 'temp_min': 42.66, 'temp_max': 43.21, 'pressure': 1029, 'humidity': 88, 'sea_level': 1029, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 2.86, 'deg': 12, 'gust': 4.54}, 'clouds': {'all': 69}, 'dt': 1632091100, 'sys': {'type': 1, 'id': 1789, 'country': 'SE', 'sunrise': 1632112612, 'sunset': 1632157505}, 'timezone': 7200, 'id': 2715459, 'name': 'Falun', 'cod': 200}
# Processing Record 50 of Set 15 | zhongxing
# zhongxing
# zhongxing
# {'coord': {'lon': 118.6792, 'lat': 33.7039}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 65.17, 'feels_like': 65.77, 'temp_min': 65.17, 'temp_max': 65.17, 'pressure': 1007, 'humidity': 93, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 12.84, 'deg': 260, 'gust': 21.45}, 'rain': {'1h': 1.78}, 'clouds': {'all': 100}, 'dt': 1632091100, 'sys': {'country': 'CN', 'sunrise': 1632088309, 'sunset': 1632132355}, 'timezone': 28800, 'id': 1784253, 'name': 'Zhongxing', 'cod': 200}
# Processing Record 1 of Set 16 | muzquiz
# muzquiz
# muzquiz
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 2 of Set 16 | puerto baquerizo moreno
# puerto baquerizo moreno
# puerto baquerizo moreno
# {'coord': {'lon': -89.6, 'lat': -0.9}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 72.59, 'feels_like': 73.45, 'temp_min': 72.59, 'temp_max': 72.59, 'pressure': 1009, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 180}, 'clouds': {'all': 75}, 'dt': 1632091101, 'sys': {'type': 1, 'id': 8546, 'country': 'EC', 'sunrise': 1632052134, 'sunset': 1632095723}, 'timezone': -21600, 'id': 3652758, 'name': 'Puerto Baquerizo Moreno', 'cod': 200}
# Processing Record 3 of Set 16 | oban
# oban
# oban
# {'coord': {'lon': -5.4706, 'lat': 56.4127}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 47.37, 'feels_like': 46.56, 'temp_min': 47.37, 'temp_max': 50.86, 'pressure': 1020, 'humidity': 94, 'sea_level': 1020, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 3.15, 'deg': 141, 'gust': 3.15}, 'clouds': {'all': 2}, 'dt': 1632091101, 'sys': {'type': 2, 'id': 2010117, 'country': 'GB', 'sunrise': 1632031276, 'sunset': 1632076209}, 'timezone': 3600, 'id': 2641108, 'name': 'Oban', 'cod': 200}
# Processing Record 4 of Set 16 | mogzon
# mogzon
# mogzon
# {'coord': {'lon': 111.9606, 'lat': 51.7435}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 44.65, 'feels_like': 44.65, 'temp_min': 44.65, 'temp_max': 44.65, 'pressure': 1012, 'humidity': 91, 'sea_level': 1012, 'grnd_level': 908}, 'visibility': 10000, 'wind': {'speed': 0.83, 'deg': 150, 'gust': 0.96}, 'clouds': {'all': 98}, 'dt': 1632091101, 'sys': {'country': 'RU', 'sunrise': 1632089676, 'sunset': 1632134212}, 'timezone': 32400, 'id': 2019884, 'name': 'Mogzon', 'cod': 200}
# Processing Record 5 of Set 16 | catio
# catio
# catio
# {'coord': {'lon': -15.25, 'lat': 11.2833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.95, 'feels_like': 79.68, 'temp_min': 77.95, 'temp_max': 77.95, 'pressure': 1014, 'humidity': 90, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 3251, 'wind': {'speed': 3.11, 'deg': 351, 'gust': 3.53}, 'rain': {'1h': 0.96}, 'clouds': {'all': 100}, 'dt': 1632091101, 'sys': {'country': 'GW', 'sunrise': 1632034219, 'sunset': 1632077959}, 'timezone': 0, 'id': 2373526, 'name': 'Catió', 'cod': 200}
# Processing Record 6 of Set 16 | mae sai
# mae sai
# mae sai
# {'coord': {'lon': 99.8762, 'lat': 20.4335}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 74.52, 'feels_like': 76.37, 'temp_min': 74.52, 'temp_max': 74.52, 'pressure': 1011, 'humidity': 100, 'sea_level': 1011, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 1.95, 'deg': 1, 'gust': 3.18}, 'clouds': {'all': 100}, 'dt': 1632091102, 'sys': {'type': 1, 'id': 9256, 'country': 'TH', 'sunrise': 1632092930, 'sunset': 1632136757}, 'timezone': 25200, 'id': 1152194, 'name': 'Mae Sai', 'cod': 200}
# Processing Record 7 of Set 16 | palmerston
# palmerston
# palmerston
# {'coord': {'lon': 130.9833, 'lat': -12.486}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.1, 'feels_like': 79.23, 'temp_min': 70.03, 'temp_max': 78.93, 'pressure': 1014, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 130}, 'clouds': {'all': 0}, 'dt': 1632091102, 'sys': {'type': 2, 'id': 2003495, 'country': 'AU', 'sunrise': 1632085637, 'sunset': 1632129122}, 'timezone': 34200, 'id': 6301965, 'name': 'Palmerston', 'cod': 200}
# Processing Record 8 of Set 16 | sambava
# sambava
# sambava
# {'coord': {'lon': 50.1667, 'lat': -14.2667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 70.77, 'feels_like': 71.55, 'temp_min': 70.77, 'temp_max': 70.77, 'pressure': 1017, 'humidity': 85, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 13.27, 'deg': 177, 'gust': 21.03}, 'rain': {'1h': 0.34}, 'clouds': {'all': 100}, 'dt': 1632091001, 'sys': {'country': 'MG', 'sunrise': 1632105031, 'sunset': 1632148511}, 'timezone': 10800, 'id': 1056899, 'name': 'Sambava', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_weather["weather"][0]["description"])
# Out:
# light rain

# %%
len(city_data)
# Out:
# 698

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Vaini -21.2000 -175.2000     77.16        73          20       12.66
# 1      Bayir  37.2687   28.2167     64.92        45           3        1.48
# 2  Jamestown  42.0970  -79.2353     74.52        49           1        4.61
# 3   Acapulco  16.8634  -99.8901     87.62        70          75        4.61
# 4    Dunedin -45.8742  170.5036     55.80        63          52       14.00
#
#   Current Description Country
# 0          few clouds      TO
# 1           clear sky      TR
# 2           clear sky      US
# 3       broken clouds      MX
# 4       broken clouds      NZ

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
